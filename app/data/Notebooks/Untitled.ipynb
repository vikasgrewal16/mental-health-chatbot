# %%
import pandas as pd

# %%
import pandas as pd

# Example dataset
data = {
    "text": [
        "I feel so stressed and anxious about my job.",
        "I'm having a wonderful day and everything is going well.",
        "I feel completely hopeless and depressed.",
        "I'm very happy today! Life is great.",
        "I have been feeling very anxious about my future.",
        "I am so sad and don't know what to do.",
        "Life is amazing and I'm enjoying every moment.",
        "I am feeling very stressed out lately.",
        "Today is a good day, I feel great!",
        "I feel so depressed and alone.",
        "I am very content with my life right now.",
        "I'm worried all the time and can't relax.",
        "I am in a really good mood today.",
        "I feel like crying all the time.",
        "I am so happy and full of energy!",
        "I can't stop worrying about everything.",
        "Life is good and I'm enjoying it.",
        "I am feeling so low and depressed.",
        "I'm feeling optimistic and happy today.",
        "I have been feeling so anxious lately.",
        "Everything is going well and I feel happy.",
        "I feel overwhelmed and stressed.",
        "I am feeling very positive today.",
        "I can't shake off this feeling of sadness.",
        "I feel calm and at peace.",
        "I am so worried about my health.",
        "I feel fantastic and on top of the world.",
        "I am so stressed about my exams.",
        "I am feeling very happy and content.",
        "I feel like everything is falling apart.",
        "I am enjoying my life and feel happy.",
        "I feel so anxious all the time.",
        "I am in a great mood today!",
        "I feel very down and depressed.",
        "I am very happy with my accomplishments.",
        "I can't help but feel anxious about the future.",
        "I am feeling very happy and positive.",
        "I feel so stressed and can't relax.",
        "I am in a good mood today.",
        "I feel sad and lonely.",
        "I am very happy with how things are going.",
        "I feel anxious and worried all the time.",
        "I am feeling great and very happy.",
        "I feel so depressed and hopeless.",
        "I am feeling very positive and happy.",
        "I can't stop worrying about my job.",
        "I feel happy and at peace with my life.",
        "I feel so stressed out about everything.",
        "I am very happy with my life."
        
    ],
    "label": [
        "anxiety",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "depression",
        "positive",
        "stress",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "stress",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "stress",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "stress",
        "positive",
        "depression",
        "positive",
        "anxiety",
        "positive",
        "stress",
        "positive",
        "anxiety",
        "positive",
        "stress",
        "positive"
    ]
}

df = pd.DataFrame(data)
df.to_csv("mental_health_data.csv", index=False)

# %%
df = pd.read_csv('mental_health_data.csv')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df["text"], df["label"], test_size=0.2, random_state=42)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

pipeline = make_pipeline(TfidfVectorizer(), LogisticRegression())

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('logisticregression', LogisticRegression())])

# %%
from sklearn.metrics import accuracy_score

y_pred = pipeline.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.4

# %%
y_pred
# Out:
# array(['anxiety', 'anxiety', 'positive', 'positive', 'positive',
#        'positive', 'positive', 'positive', 'anxiety', 'positive'],
#       dtype=object)

# %%
y_test
# Out:
# 13    depression
# 45       anxiety
# 47        stress
# 44      positive
# 17    depression
# 27        stress
# 26      positive
# 25       anxiety
# 31       anxiety
# 19       anxiety
# Name: label, dtype: object

# %%
X_test
# Out:
# 13             I feel like crying all the time.
# 45          I can't stop worrying about my job.
# 47     I feel so stressed out about everything.
# 44        I am feeling very positive and happy.
# 17           I am feeling so low and depressed.
# 27             I am so stressed about my exams.
# 26    I feel fantastic and on top of the world.
# 25             I am so worried about my health.
# 31              I feel so anxious all the time.
# 19       I have been feeling so anxious lately.
# Name: text, dtype: object

# %%
X_train
# Out:
# 12                    I am in a really good mood today.
# 4     I have been feeling very anxious about my future.
# 34             I am very happy with my accomplishments.
# 8                    Today is a good day, I feel great!
# 3                  I'm very happy today! Life is great.
# 6        Life is amazing and I'm enjoying every moment.
# 40           I am very happy with how things are going.
# 41             I feel anxious and worried all the time.
# 46              I feel happy and at peace with my life.
# 15              I can't stop worrying about everything.
# 9                        I feel so depressed and alone.
# 16                    Life is good and I'm enjoying it.
# 24                            I feel calm and at peace.
# 33                      I feel very down and depressed.
# 30                I am enjoying my life and feel happy.
# 0          I feel so stressed and anxious about my job.
# 43                    I feel so depressed and hopeless.
# ...

# %%
y_train
# Out:
# 12      positive
# 4        anxiety
# 34      positive
# 8       positive
# 3       positive
# 6       positive
# 40      positive
# 41       anxiety
# 46      positive
# 15       anxiety
# 9     depression
# 16      positive
# 24      positive
# 33    depression
# 30      positive
# 0        anxiety
# 43        stress
# 32      positive
# 5     depression
# 29    depression
# 11       anxiety
# 36      positive
# 1       positive
# 21        stress
# 2     depression
# 37        stress
# 35       anxiety
# 23    depression
# 39    depression
# 10      positive
# 22      positive
# 18      positive
# 48      positive
# 20      positive
# 7         stress
# 42      positive
# 14      positive
# 28      positive
# 38      positive
# Name: label, dtype: object

# %%
y_test
# Out:
# 13    depression
# 45       anxiety
# 47        stress
# 44      positive
# 17    depression
# 27        stress
# 26      positive
# 25       anxiety
# 31       anxiety
# 19       anxiety
# Name: label, dtype: object
